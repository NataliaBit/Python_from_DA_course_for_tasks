# %% [markdown]
# ## Домашнє завдання 6: Статистичні тести

# %% [markdown]
# 0. Зчитайте дані з `data.csv` та запишіть значення колонки data у форматі np.ndarray в змінну data. Ми будемо далі працювати з цією змінною.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np

df = pd.read_csv('/content/drive/MyDrive/data_statistics/data.csv')
data = df['data'].to_numpy()

data.shape
# Out:
# (100,)

# %% [markdown]
# Запустіть код нижче. Для коректної робити всіх подальших методів дані мають бути у вигляді одновимірного вектора, тобто мати розмір (100,).

# %% [markdown]
# 1. Зчитані дані - це сума покупок в доларах наших покупців на сайті протягом липня 2022 року.
#
# До цього місяця, ми мали продажі в середньому на чек $20. Чи вийшло у нас статистично значущо **підвищити** середній чек за останній місяць?
#
# Оберіть статистичний тест (z-test чи t-test). Виведіть p-значення статистичного тесту та зробіть висновок, чи ми маємо зараз статистично значущу різницю у розмірі середнього чеку.
#
# **Підказка**: тут тест буде одновибірковий.

# %%
import numpy as np
from scipy import stats
n = len(data)
mean_value = data.mean()

std_value = data.std(ddof=1)

# Нульова гіпотеза H₀: μ = 20, сума чека - 20 доларів
# Альтернативна гіпотеза H₁: μ > 20, сума чека становить більше 20 доларів
# одновибірковий t-test
# візьмемо α = 0,05 (5%)
t_stat, p_value = stats.ttest_1samp(
    data,
    popmean=20,
    alternative='greater'
)

# %%
alpha = 0.05

if p_value < alpha:
    print("Відхиляємо H₀: середній чек статистично значуще більший за 20 доларів")
else:
    print("Немає підстав відхиляти H₀: статистично значущої різниці немає")
# Out:
# Немає підстав відхиляти H₀: статистично значущої різниці немає

# %% [markdown]
# 2. Пройшов час, і ми зібрали дані про продажі за серпень 2022 року, які зберігли у файл `data_2.csv`. Продажів було дещо більше, але чи змінився стат. значущо середній чек порівняно з липнем 2022? Перевірте це використовуючи ztest.
#
#   Виведіть p-значення статистичного тесту та зробіть висновок, чи ми маємо зараз статистично значущу різницю у розмірі середнього чека між двома місяцями.
#
#   **Підказка**: треба провести двовибірковий ztest з Н0 - що середні значення в липні та серпні 2022 року - однакові. Для кращого розуміння ситуації, можливо вам буде цікаво переглянути, які середні показники чеку були в кожен з місяців. Порівняйте свій висновок з простого спостереження середніх значень і висновок статистичного тесту. Чи вони збігаються?

# %%
df_july = pd.read_csv('/content/drive/MyDrive/data_statistics/data.csv')
data = df_july['data'].to_numpy()

# %%
df_august = pd.read_csv('/content/drive/MyDrive/data_statistics/data_2.csv')
data_2 = df_august['data'].to_numpy()

# %%
# Позначимо окремо дані липня та серпня як df_july та df_august, щоб побачити середнє значення в чеках за ці два місяці і порівняти іх

# %%
print("July mean:", data.mean())
print("August mean:", data_2.mean())
# Out:
# July mean: 19.37755319670441
# August mean: 19.37322276512519

# %%
# Як бачимо, різниці в середніх значеннях даних в чеках за липень і серпень майже немає, що підтверджує попередньо нульову гіпотезу H0
 (середні значення в липні та серпні 2022 року -  однакові.)

# %%
z_stat, p_value = ztest(data, data_2, alternative='two-sided')

print("z-statistic:", z_stat)
print("p-value:", p_value)
# Out:
# z-statistic: 0.005246673456808504
# p-value: 0.9958137794593356

# %%
alpha = 0.05

if p_value < alpha:
    print("Відхиляємо H₀: різниця статистично значуща")
else:
    print("Не відхиляємо H₀: статистично значущої різниці немає")
# Out:
# Не відхиляємо H₀: статистично значущої різниці немає

# %%
# Висновок.
При порівнянні середніх значень чеків у липні та серпні 2022 року за допомогою двовибіркового z-test при рівні значущості α = 0.05
ми отримали p-value > 0.05, тому ми не відхиляємо нульову гіпотезу.
Отже, статистично значущої різниці між середніми чеками у липні та серпні 2022 року не виявлено.
Висновок статистичного тесту узгоджується з порівнянням середніх значень.
